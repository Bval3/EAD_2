# %% [markdown]
# # Team members
# ### 1. Reece Pennington
# ### 2. Benjamin Valenzuela

# %% [markdown]
# # About Dataset
# ### Data Science Job Salaries Dataset contains 11 columns, each are:
#
# - work_year: The year the salary was paid.
# - experience_level: The experience level in the job during the year
# - employment_type: The type of employment for the role
# - job_title: The role worked in during the year.
# - salary: The total gross salary amount paid.
# - salary_currency: The currency of the salary paid as an ISO 4217 currency code.
# - salaryinusd: The salary in USD
# - employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code.
# - remote_ratio: The overall amount of work done remotely
# - company_location: The country of the employer's main office or contracting branch
# - company_size: The median number of people that worked for the company during the year

# %%
# Install the required libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Steps of EAD
# ### 1. Loading and Inspecting Data
#
# Core pandas functions:
# - df.head()
# - df.tail()
# - df.shape
# - df.columns
# - df.info()
# - df.describe()
# - df.dtypes

# %%
#Load the data set and use info() columns shape and head() te get a preview and underestanding of data
salarydf = pd.read_csv("ds_salaries.csv")
salarydf.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
salarydf.shape
# Out:
# (607, 11)

# %%
salarydf.tail()
# Out:
#      work_year experience_level employment_type      job_title  salary  \
# 602       2022               SE              FT  Data Engineer  154000
# 603       2022               SE              FT  Data Engineer  126000
# 604       2022               SE              FT   Data Analyst  129000
# 605       2022               SE              FT   Data Analyst  150000
# 606       2022               MI              FT   AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602             USD         154000                 US           100
# 603             USD         126000                 US           100
# 604             USD         129000                 US             0
# 605             USD         150000                 US           100
# 606             USD         200000                 IN           100
#
#     company_location company_size
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L

# %% [markdown]
# ### 2. Understanding Variables
#
# Categorical vs Numerical Variables
#
# - Continuous vs Discrete
#
# - Nominal vs Ordinal
#
# Useful functions:
# - df['column'].unique()
# - df['column'].value_counts()
# - df['column'].nunique()

# %%
salarydf.nunique()
# Out:
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %% [markdown]
# ### 3. Handling Missing Data
# Key functions:
#
# - df.isnull()
# - df.isnull().sum()
# - df.dropna()
# - df.fillna()

# %%
salarydf.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# ### 4. Descriptive Statistics
# Numerical:
# - `df.describe()`
# - `df.mean()`
# - `df.median()`
# - `df.std()`
# - `df.min()`
# - `df.max()`
# - `df.quantile()`
#
# Categorical:
# - `df["Category"].mode()`
# - `df["Category"].describe()`

# %%
salarydf.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count   607.000000  6.070000e+02     607.000000     607.00000
# mean   2021.405272  3.240001e+05  112297.869852      70.92257
# std       0.692133  1.544357e+06   70957.259411      40.70913
# min    2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    2022.000000  1.650000e+05  150000.000000     100.00000
# max    2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# ### 5. Grouping and Aggregation
# Concepts:
#
# - Aggregation
# - Multi-level grouping
# - Count vs size
# - Resetting index
#
# Syntax:
# - `df.groupby('Category').mean()`
# - `df.groupby(['Category','Gender']).agg(['mean','count'])`

# %%
# [Optional] You may choose to perform grouping and aggregation to generate additional results or visualizations for deeper data analysis.
occupationdf = salarydf.groupby('job_title')["salary"].mean().sort_values(ascending = False).reset_index()
occupationdf
# Out:
#                                    job_title        salary
# 0                   Head of Machine Learning  6.000000e+06
# 1                                ML Engineer  2.676667e+06
# 2                            BI Data Analyst  1.902045e+06
# 3                        Lead Data Scientist  1.101667e+06
# 4                       Data Science Manager  1.062599e+06
# 5                          Lead Data Analyst  5.690000e+05
# 6                             Data Scientist  5.083472e+05
# 7                          Big Data Engineer  4.550000e+05
# 8                        Data Analytics Lead  4.050000e+05
# 9              3D Computer Vision Researcher  4.000000e+05
# 10                     Business Data Analyst  3.550000e+05
# 11                   Principal Data Engineer  3.283333e+05
# 12                              AI Scientist  2.905714e+05
# 13                    Financial Data Analyst  2.750000e+05
# 14                 Machine Learning Engineer  2.727179e+05
# 15                              NLP Engineer  2.400000e+05
# 16                      Product Data Analyst  2.350000e+05
# 17                  Principal Data Scientist  2.067143e+05
# 18                  Director of Data Science  1.932857e+05
# 19                             Data Engineer  1.792106e+05
# 20                            Data Architect  1.778739e+05
# 21                        Analytics Engineer  1.750000e+05
# 22                    Applied Data Scientist  1.724000e+05
# 23                           Data Specialist  1.650000e+05
# 24                Machine Learning Scientist  1.584125e+05
# 25                  Machine Learning Manager  1.570000e+05
# 26                              Head of Data  1.564000e+05
# 27                      Head of Data Science  1.467188e+05
# 28        Applied Machine Learning Scientist  1.413500e+05
# 29              Director of Data Engineering  1.412500e+05
# 30                        Lead Data Engineer  1.403333e+05
# 31                       Cloud Data Engineer  1.400000e+05
# 32                    Data Analytics Manager  1.271343e+05
# 33                        Big Data Architect  1.250000e+05
# 34                   Data Science Consultant  1.227143e+05
# 35                    Principal Data Analyst  1.225000e+05
# 36                  Data Engineering Manager  1.197998e+05
# 37                        Research Scientist  1.104937e+05
# 38                      Staff Data Scientist  1.050000e+05
# 39         Computer Vision Software Engineer  1.003333e+05
# 40                Machine Learning Developer  1.000000e+05
# 41  Machine Learning Infrastructure Engineer  9.733333e+04
# 42                              Data Analyst  9.660496e+04
# 43                     Data Science Engineer  8.450000e+04
# 44                  Computer Vision Engineer  8.350000e+04
# 45            Lead Machine Learning Engineer  8.000000e+04
# 46                    Marketing Data Analyst  7.500000e+04
# 47                   Data Analytics Engineer  6.175000e+04
# 48                             ETL Developer  5.000000e+04
# 49                      Finance Data Analyst  4.500000e+04

# %% [markdown]
# ### 6. Data Distribution & Visualization
# visualization is essential for EAD.
#
# Useful Diagram:
# - Countplot
# - Barplot
# - Lineplot (time trends)
# - Histogram
# - Boxplot
# - pairplot

# %% [markdown]
# ### Pairwise relationships between numerical variables

# %%
# use hue='experience_level' in your pair plot
sns.pairplot(data=salarydf, hue='experience_level')
plt.show()

# %% [markdown]
# ### 7. Correlation & Relationships
#
# Useful functions and diagrams:
# - `df.corr()`
# - `pd.crosstab(df["Category"], df["Another_Category"])`
# - `sns.heatmap(df.corr())`

# %% [markdown]
# ### Visualize the Correlation map for work_year and salary

# %%
heatmap = salarydf[['work_year','salary']]
matrix = heatmap.corr(method = 'pearson')
sns.heatmap(matrix, annot=True)
plt.show()

# %% [markdown]
# ### Your Observations:
# #### write your observation about above plot in this cell
# ##### Work year and salary have a very weak negatively correlated relationship. Therefore, commenting on the nature of their relationship is not statistically reliable.

# %% [markdown]
# ### Create a Barplot to identify which year has the most data scientist salary records in the dataset

# %%
datas = salarydf[salarydf['job_title']=='Data Scientist']
sns.countplot(data=datas, x=salarydf['work_year'])
plt.title('Year Wise Data Scientist salries in the data')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Your Observations:
# #### write your observation about above plot in this cell
# ##### In the distribution, 2022 has the highest amount of data scientist salaries. Additionally, there is a visible trend in the data, where the count of data scientist salaries increase yearly.

# %% [markdown]
# ### Use a pie chart to show the distribution of experience levels in the dataset.

# %%
#Use the explode parameter and set it to explode = [0.05, 0.04, 0.05, 0.06] to display the pie chart with separated slices.
salarydf['experience_level'].value_counts().plot(kind='pie',explode = [0.05,0.04,0.04,0.06],autopct='%0.2f%%')
plt.title('Experience')
plt.show()

# %% [markdown]
# ### Your Observations:
# #### write your observation about above plot in this cell
# ##### The two largest group of experience levels within the distribution are mid level occupations, and senior level occupations. with executive positions and entry level positions being the two smallest. The largest overall group is the senior level occupation, while the overall smallest is the entry level occupation.

# %% [markdown]
# ### Create histogram to understand Salary distribution by Experience level
# use salary_in_usd

# %%
# Use histplot with Kernel density estimate (kde=True) 
sns.histplot(salarydf, x='salary_in_usd', hue ='experience_level', kde=True)
plt.title('Understanding the salary_usd with Experience level')
plt.show()

# %% [markdown]
# ### Plot a histogram to explore the distribution of data scientist salaries based on company size.

# %%
sns.histplot(salarydf, x='salary_in_usd', hue ='company_size', kde=True)
plt.title('Distribution of data salaries based on company size')
plt.show()

# %% [markdown]
# ### Observations:
# #### write your observation about above plot in this cell
# ##### Both plots appear to be skewed right with high outliers. In the first plot

# %% [markdown]
# ### Visualize a bar chart showing the average salary of data scientists by experience level.

# %%
avgs = (
    salarydf.groupby('experience_level')['salary_in_usd']
            .mean()
            .reset_index()
)

# Optional: sort by experience level if needed
# avgs = avgs.sort_values('experience_level')
=
ax = avgs.plot(
    kind='bar',
    x='experience_level',
    y='salary_in_usd',
    color=['Red', 'Blue', 'Green', 'Purple'],
    figsize=(8,6),
    legend=False
)
ax.set_xlabel("Experience Level")
ax.set_ylabel("Average Salary (USD)")
ax.set_title("Average Salary by Experience Level")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Visualize a bar chart showing the average salary of data scientists by job title.

# %% [markdown]
# ### Observations:
# #### write your observation about above plots in this cell

# %% [markdown]
# ### How much small companys pay for the different roles and who are the highest paid

# %%
small_df = salarydf[salarydf["company_size"] == "S"]
df_order = small_df.groupby("job_title")["salary_in_usd"].sum().sort_values(ascending = False).index
sns.barplot(data = small_df, x = "job_title", y = "salary_in_usd", estimator = sum, errorbar = None, palette = "viridis", order = df_order)
plt.xticks(rotation = 90)
plt.title("Sum of Salary in Small Companies by Job Title")
plt.xlabel("Job")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# ### Observations:
# #### write your observation about above plot in this cell
# #### This barplot shows the total salary of a certain job position in small companies. Data scientists, cumulitively, make the most in small companies, and Product Data Analysts make the least.

# %% [markdown]
# ### Top 10 most demanding job in the USA

# %%
USdf = salarydf[salarydf["company_location"] == "US"]
top10 = USdf.groupby("job_title")["salary_in_usd"].sum().sort_values(ascending = False).head(10).index
sns.barplot(data = USdf, x = "job_title", y = "salary_in_usd", estimator = sum, errorbar = None, palette = "viridis", order = top10)
plt.xticks(rotation = 90)
plt.title("Most Demanding Jobs in the USA")
plt.xlabel("Job")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# ### Find the Average Salary paying the large companys with employement wise

# %%
large_df = salarydf[salarydf["company_size"] == "L"]
large_order = large_df.groupby("job_title")["salary_in_usd"].mean().sort_values(ascending = False).index
sns.barplot(data = large_df, x = "job_title", y = "salary_in_usd", errorbar = None, palette = "viridis", order = large_order)
plt.xticks(rotation = 90)
plt.title("Average Salary by Position in Large Companies")
plt.xlabel("Job")
plt.ylabel("Salary in USD")
plt.show()

# %% [markdown]
# ### Observations:
# #### write your observations in this cell
# #### The most demanding job in the USA is Data Scientist, while the least is Machine Learning Scientist.
# #### The highest average salary in large companies is the Data Analytics Lead, and the lowest average salary is the Product Data Analyst.

# %% [markdown]
# # Word Cloud
# #### run two following cells

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\jerry\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\jerry\anaconda3\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in c:\users\jerry\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jerry\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jerry\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.6

# %%
#We import the wordcloud from the 
from wordcloud import WordCloud
text3 = ' '.join(salarydf['job_title'])
wordcloud2 = WordCloud(mode='RGB',background_color='white').generate(text3)

# Generate plot
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Explain what a word cloud is and why we use word clouds.
#
# ### Discuss your observations based on the result of the above code.

# %% [markdown]
# ### A word cloud shows the more frequently recurring results as a larger font size, and the less common results as a smaller font size. It is a unique way to display the count of certain values in a dataset.
# ### The most common jobs in this dataset are Data Scientist, Data Engineers, and Data Analysts. Less common jobs include Directors, Developers, Research Scientists, and Analytics Manager.
